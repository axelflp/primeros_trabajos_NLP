# %%
import os

# %%
os.chdir(r"C:\Users\HP\Python\LC_ByR")

# %% [markdown]
# Corpus extraido de [aquí](https://www.kaggle.com/leangab/poe-short-stories-corpuscsv)

# %% [markdown]
# # Paquetería

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from re import compile
import re
from collections import defaultdict, OrderedDict, Counter
from itertools import chain, combinations
import operator
import string

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Funciones

# %% [markdown]
# ## Función de tokenización

# %%
regex = compile('[_{}();\.,+:!\[0-9\]$\*"&#\/¡!¿?·''`“”‘’]')                 
    
def tokenize(text):
    """
    Función de tokenización.
    
    Arguments
    ---------
    text : str
        Cadena de texto que se tokenizará
        
    Returns
    -------
    tokens : list
        Lista de tokens
    """

    
    #Retiramos signos
    text= regex.sub(' ',text.lower())
    tok = text.split(' ')
    
    #Pasamos los tokens limpios a la lista tokens
    tokens = []
    for t in tok:
        #Retiramos ' al principio y al final de las string
        #No retiramos todas las ' pues hay palabras que no se entienderian sin '
        if "'" in t:
            a = re.sub("^'",'',t)
            a = re.sub("'$",'',a)
            tokens.append(a)
        #Retiramos las string vacias, pues nuestro corpus las genera por su estructura
        elif t == '':
            pass
        else:
            tokens.append(t)

    return tokens

# %% [markdown]
# ## Función para frecuencias de tipos
# A partir de la lista de tokens

# %%
def freq(tokens):
    """
    Función que calcula la frecuencia absoluta de palabras en una lista.
    
    Arguments
    ---------
    tokens : list
        Documento tokenizado
        
    Returns
    -------
    fr : defaultdict
        Diccionario de tokens (tipos) con frecuencias absolutas
    """
    fr = defaultdict(int)
    
    #Conteo de tipos en diccionario, con key igual al tipo dividido por ' ', más </w>
    for i in tokens:
        fr[' '.join(i)+' </w>'] += 1
    
    return fr

# %% [markdown]
# ## Función para frecuencias de caracteres
# A partir de diccionario de frecuencias por tipos

# %%
def freq_w(dicc):
    """
    Función que calcula frecuencia absoluta de caracteres y total de palabras.
    
    Arguments
    ---------
    dicc : dict
        Diccionario de las frecuencias de las palabras (tipos)
        
    Returns
    -------
    freq_o : OrderedDict
        Diccionario ordenado de las frecuencias de los carateres y cantidad de palabras
    """
    freq = defaultdict(int)
    
    #Contabilizamos palabras y carácteres
    for w, f in dicc.items():
        #Conteo de palabras
        if '</w>' in w:
            freq['</w>'] += f
            w = re.sub(' </w>','',w)
        #Conteo de caracteres
        for ch in w.split():
            freq[ch] += f
    
    #Ordenamos el diccionnario teninendo como primer key a '</w>'
    freq_o = OrderedDict()
    freq_o['</w>']=freq['</w>']
    del freq['</w>']
    freq_o.update(dict(sorted(freq.items(), key = operator.itemgetter(1), reverse=True)))
    
    return freq_o

# %% [markdown]
# ## Función para obtener el par de simbolos consecutivos más común y unirlos en el diccionario de frecuencias de tipos
# A partir de un diccionario de frecuencias de tipos, y un alfabeto con subwords y sus frecuencias

# %%
def par_com(dic_freq,al):
    """
    Función para unir par de caracteres más común, y calcular su frecuencia absoluta
    
    Arguments
    ---------
    dic_freq : dict
        Diccionario de frecuencias de palabras
    al : dict
        Lista de carácteres 'básicos' (subwords) con fecuencias
        
    Returns
    -------
    prod : list
        Lista con:
            [0] dic_fr_ord: palabras y frecuencias
            [1] alf_ord: subwords y frecuencias
            [2] tupla con par más común y su frecuencia
            
            
    """
    
    alf = al.copy()
    dic_fr = dic_freq.copy()
    alf.pop('</w>',None)
    
    
    
    voc = defaultdict(int)
    keys = defaultdict(list)
    
    #Contabilizamos la frecuencia de caracteres básicos consecutivos
    for word in dic_fr:
        w = re.sub(' </w>','',word)
        w = w.split()
        for i in range(len(w)-1):
            voc[w[i],w[i+1]] += dic_fr[word]
            keys[(w[i],w[i+1])] += [word]
    
    #Par de caracteres consecutivos más común
    max_key = max(voc.items(), key=operator.itemgetter(1))[0]
    pri, sec = max_key
    
    #Diccionario con el par de caracteres con mayor frecuencia unidos
    dic_fr0 = {word : fr for word, fr in dic_fr.items() if word not in keys[max_key]}
    for word in keys[max_key]:
        w = word.split()
        c=0
        for i in range(len(w)-1):
            if w[i]==pri and w[i+1]==sec:
                w[i] = pri+sec
                del w[i+1]
                c += 1
            if i+1 > len(w)-(2+c):
                break
        dic_fr0[' '.join(w)] = dic_fr[word] 
    
    
    #Ordenando diccionario de palabras por frecuencia
    dic_fr_ord = OrderedDict()
    dic_fr_ord.update(dict(sorted(dic_fr0.items(), key = operator.itemgetter(1), reverse=True)))

    #Actualizando diccionnario de subwords
    alf[pri+sec] = voc[max_key]
    alf[pri] -= voc[max_key]
    alf[sec] -= voc[max_key]
    
    #Ordenando diccionario de subwords por frecuencia
    alf_ord = OrderedDict()
    alf_ord.update(dict(sorted(alf.items(), key = operator.itemgetter(1), reverse=True)))
    
    prod = [dic_fr_ord, alf_ord, (max_key,'Frecuencia: '+str(voc[max_key]))]
    
    #dic_fr_ord: palabras y frecuencias
    #alf_ord: subwords y frecuencias
    #tupla con par más común y su frecuencia
    
    return prod

# %% [markdown]
# ## Función de sustitución

# %%
def sus(corpus, dicc_s):
    """
    Función que calcula frecuencia absoluta de caracteres y total de palabras.
    
    Arguments
    ---------
    corpus : dict
        Corpus
    dicc_s : dict
        Diccionario con número de iteración como clave y tupla con regla de sustitución como valor
        
    Returns
    -------
    n_corpus : dict
        Corpus con la sustitucion dada por dicc_s
    """
    
    c_corpus = corpus.copy()
    
    #Sustituimos las subwords en el corpus
    for i in reversed(range(len(dicc_s))):
        orig = dicc_s[i][0]
        dest = dicc_s[i][1]
        for tit, tx in c_corpus.items():
            c_corpus[tit] = re.sub(orig,dest,tx)
    
    return c_corpus

# %% [markdown]
# # Clase _BPE_Tokenization_
# Para aplicar la tokenización BPE sobre un corpus en forma de diccionario

# %%
class BPE_Tokenization(object): 

    def  __init__ (self, corpus):
            
        """
        Clase para tokenización BPE.
        
        Arguments
        ---------
        
        corpus : dict
            Colección de documentos 
            {title:text}
        """
        for i in corpus:
            corpus[i] = corpus[i].lower()
        self.corpus = corpus
        self.frecuencias = None
        self.vocabulario = None
        self.tokens = None
        self.pares = None
        self.asignacion = dict()
        self.iteraciones = 0
        #Curpus con subwords sustituidas
        self.ncorpus = None
        
        
    def tokenizar(self,iteraciones):
        
        self.iteraciones = iteraciones
        
        #Inicializando los atributos para cada invocacion del metodo tokenizar()
        self.frecuencias = None
        self.vocabulario = None
        self.tokens = []
        self.pares = OrderedDict()
        self.asignacion = dict()
        
        #Tokenizando corpus
        for doc in self.corpus:
            self.tokens += tokenize(self.corpus[doc])
        
        #Calculando frecuencias absolutas de tipos y caracteres 
        self.frecuencias = freq(self.tokens)
        self.vocabulario = freq_w(self.frecuencias)
        
        #Pares más comunes por iteración
        for i in range(self.iteraciones):
            self.frecuencias, self.vocabulario, par = par_com(self.frecuencias, self.vocabulario)
            self.pares.update({i:par})
        
            
        #Letras con las que vamos a sustituir las subwords
        abc = ' '.join(string.ascii_uppercase).split()
        
        
        if self.iteraciones>len(abc):
            #Si el número de iteraciones supera el total de letras 
            #que tenemos para sustituir las subwords no hacemos la sustitucioó
            print('Se han generado más de ',len(abc),' iteraciones')
        else:
            #Sustituyendo subwords por letras del abecedario en mayusculas
            for i in range(self.iteraciones):
                self.asignacion[i] = (''.join(self.pares[i][0]),abc[i])
            self.ncorpus = sus(self.corpus, self.asignacion)

# %% [markdown]
# # Tokenización BPE

# %%
data = pd.read_csv(r"Poe.csv")

Corpus = {data.title[i]:data.text[i] for i in range(data.shape[0])}

# %%
prueba = BPE_Tokenization(Corpus)

# %%
prueba.tokenizar(7)

# %%
#Pares más comunes por iteración
prueba.pares
# Out:
# OrderedDict([(0, (('t', 'h'), 'Frecuencia: 48570')),
#              (1, (('th', 'e'), 'Frecuencia: 31317')),
#              (2, (('i', 'n'), 'Frecuencia: 28875')),
#              (3, (('a', 'n'), 'Frecuencia: 22216')),
#              (4, (('e', 'r'), 'Frecuencia: 21554')),
#              (5, (('o', 'n'), 'Frecuencia: 18171')),
#              (6, (('r', 'e'), 'Frecuencia: 17718'))])

# %%
#Regla de sustitución
prueba.asignacion
# Out:
# {0: ('th', 'A'),
#  1: ('the', 'B'),
#  2: ('in', 'C'),
#  3: ('an', 'D'),
#  4: ('er', 'E'),
#  5: ('on', 'F'),
#  6: ('re', 'G')}

# %%
#Corpus con sustitución
tit = list(prueba.ncorpus.keys())
print('Titulo:\n','\t'+tit[0]+'\n','Extracto:\n','\t'+prueba.ncorpus[tit[0]],sep='')
# Out:
# Titulo:
# 	A DESCENT INTO THE MAELSTRÖM
# Extracto:
# 	B ways of god C natuG, as C providence, aG not as our ways; nor aG B models Aat we frame Dy way commensurate to B vastness, profundity, Dd unsearchableness of his works, which have a depA C Bm gGatE AD B well of democritus. joseph glDville.    we had now Gached B summit of B loftiest crag. for some mCutes B old mD seemed too much exhausted to speak.     “not lFg ago,” said he at lengA, “Dd i could have guided you F Ais route as well as B youngest of my sFs; but, about AGe years past, BG happened to me D event such as nevE happened to mortal mD—or at least such as no mD evE survived to tell of—Dd B six hours of deadly tEror which i Bn enduGd have broken me up body Dd soul. you suppose me a vEy old mD—but i am not. it took less AD a sCgle day to chDge Bse hairs from a jetty black to white, to weaken my limbs, Dd to unstrCg my nEves, so Aat i tGmble at B least exEtiF, Dd am frightened at a shadow. do you know i cD scarcely look ovE Ais little cliff wiAout gettCg giddy?”     B “little cliff,” upF whose edge he had so caGlessly Arown himself down to Gst Aat B weightiE portiF of his body hung ovE it, while he was Fly kept from fallCg by B tenuG of his elbow F its extGme Dd slippEy edge—Ais “little cliff” arose, a sheE unobstructed pGcipice of black shCCg rock, some fifteen or sixteen hundGd feet from B world of crags beneaA us. noACg would have tempted me to wiAC half a dozen yards of its brCk. C truA so deeply was i excited by B pEilous positiF of my compDiF, Aat i fell at full lengA upF B ground, clung to B shrubs around me, Dd daGd not even glDce upward at B sky—while i struggled C vaC to divest myself of B idea Aat B vEy foundatiFs of B mountaC weG C dDgE from B fury of B wCds. it was lFg befoG i could GasF myself Cto sufficient courage to sit up Dd look out Cto B distDce.     “you must get ovE Bse fDcies,” said B guide, “for i have brought you heG Aat you might have B best possible view of B scene of Aat event i mentiFed—Dd to tell you B whole story wiA B spot just undE your eye.”     “we aG now,” he cFtCued, C Aat particularizCg mDnE which distCguished him—“we aG now close upF B norwegiD coast—C B sixty-eighA degGe of latitude—C B gGat provCce of nordlDd—Dd C B dGary district of lofoden. B mountaC upF whose top we sit is helseggen, B cloudy. now raise yourself up a little highE—hold F to B grass if you feel giddy—so—Dd look out, beyFd B belt of vapor beneaA us, Cto B sea.”     i looked dizzily, Dd beheld a wide expDse of oceD, whose watEs woG so Cky a hue as to brCg at Fce to my mCd B nubiD geographE’s account of B maG tenebrarum. a pDorama moG deplorably desolate no humD imagCatiF cD cFceive. to B right Dd left, as far as B eye could Gach, BG lay outstGtched, like ramparts of B world, lCes of horridly black Dd beetlCg cliff, whose charactE of gloom was but B moG forcibly illustrated by B surf which GaGd high up agaCst its white Dd ghastly cGst, howlCg Dd shriekCg foGvE. just opposite B promFtory upF whose apex we weG placed, Dd at a distDce of some five or six miles out at sea, BG was visible a small, bleak-lookCg islDd; or, moG propEly, its positiF was discEnible Arough B wildEness of surge C which it was enveloped. about two miles neaGr B lDd, arose DoAE of smallE size, hideously craggy Dd barGn, Dd encompassed at various CtEvals by a clustE of dark rocks.     B appearDce of B oceD, C B space between B moG distDt islDd Dd B shoG, had someACg vEy unusual about it. alAough, at B time, so strFg a gale was blowCg lDdward Aat a brig C B Gmote offCg lay to undE a double-Gefed trysail, Dd cFstDtly plunged hE whole hull out of sight, still BG was heG noACg like a Ggular swell, but Fly a short, quick, Dgry cross dashCg of watE C evEy diGctiF—as well C B teeA of B wCd as oAEwise. of foam BG was little except C B immediate vicCity of B rocks.     “B islDd C B distDce,” Gsumed B old mD, “is called by B norwegiDs vurrgh. B Fe midway is moskoe. Aat a mile to B norAward is ambaaGn. yFdE aG islesen, hoAolm, keildhelm, suarven, Dd buckholm ...

# %%
#Frecuencias de simbolos básicos
prueba.vocabulario
# Out:
# OrderedDict([('e', 122038),
#              ('a', 95371),
#              ('o', 94812),
#              ('t', 93404),
#              ('s', 91463),
#              ('i', 81302),
#              ('d', 62460),
#              ('l', 60435),
#              ('r', 47352),
#              ('u', 44276),
#              ('c', 40901),
#              ('h', 40262),
#              ('m', 39851),
#              ('f', 38066),
#              ('n', 36159),
#              ('the', 31317),
#              ('w', 30926),
#              ('p', 29961),
#              ('in', 28875),
#              ('y', 28838),
#              ('g', 27703),
#              ('b', 23623),
#              ('an', 22216),
#              ('er', 21554),
#              ('on', 18171),
#              ('re', 17718),
#              ('th', 17253),
#              ('v', 16248),
#              ('k', 7553),
#              ('—', 4926),
#              ('x', 3206),
#              ('-', 2517),
#              ('q', 1775),
#              ('j', 1430),
#              ('z', 1063),
#              ('é', 31),
#              ('ö', 19),
#              ('ê', 13),
#              ('æ', 11),
#              ('à', 10),
#              ('è', 7),
#              ('~', 7),
#              ('â', 5),
#              ('ä', 3),
#              ('ô', 2),
#              ('ü', 1),
#              ('î', 1),
#              ('û', 1),
#              ('ç', 1)])

# %%
#Frecuencia de palabras
prueba.frecuencias
# Out:
# OrderedDict([('the </w>', 24634),
#              ('o f </w>', 14800),
#              ('an d </w>', 9390),
#              ('t o </w>', 7769),
#              ('a </w>', 7704),
#              ('in </w>', 6746),
#              ('i </w>', 6004),
#              ('i t </w>', 3860),
#              ('th a t </w>', 3838),
#              ('w a s </w>', 3738),
#              ('w i th </w>', 2848),
#              ('m y </w>', 2750),
#              ('i s </w>', 2692),
#              ('a s </w>', 2605),
#              ('a t </w>', 2573),
#              ('w h i c h </w>', 2439),
#              ('h i s </w>', 2256),
#              ('h a d </w>', 2176),
#              ('h e </w>', 2162),
#              ('f o r </w>', 2125),
#              ('n o t </w>', 2032),
#              ('th i s </w>', 2021),
#              ('b y </w>', 1975),
#              ('b e </w>', 1815),
#              ('b u t </w>', 1772),
#              ('h a v e </w>', 1737),
#              ('u p on </w>', 1615),
#              ('f r o m </w>', 1574),
#              ('a l l </w>', 1451),
#              ('m e </w>', 1389),
#              ('n o </w>', 1349),
#              ('w e </w>', 1332),
#              ('o r </w>', 1311),
#              ('an </w>', 1307),
#              ('s o </w>', 1238),
#              ('y o u </w>', 1214),
#              ('w er e </w>', 1189),
#              ('b e e n </w>', 1167),
#              ('i t s </w>', 1005),
#              ('on e </w>', 1005),
#              ('the re </w>', 1004),
#              ('v er y </w>', 921),
#              ('on </w>', 918),
#              ('h er </w>', 909),
#              ('m o re </w>', 871),
#              ('a re </w>', 855),
#              ('n o w </w>', 764),
#              ('h i m </w>', 763),
#              ('th an </w>', 755),
#              ('w h a t </w>', 746),
#              ('s o m e </w>', 725),
#              ('s </w>', 725),
#              ('c o u l d </w>', 724),
#              ('in t o </w>', 718),
#              ('w o u l d </w>', 697),
#              ('w h e n </w>', 672),
#              ('an y </w>', 639),
#              ('w i l l </w>', 637),
#              ('a b o u t </w>', 625),
#              ('the i r </w>', 611),
#              ('s a i d </w>', 591),
#              ('i f </w>', 572),
#              ('the s e </w>', 567),
#              ('the n </w>', 559),
#              ('w h o </w>', 555),
#              ('o u r </w>', 548),
#              ('u p </w>', 546),
#              ('the y </w>', 536),
#              ('m o s t </w>', 526),
#              ('h a s </w>', 497),
#              ('s a y </w>', 468),
#              ('on l y </w>', 463),
#              ('l i t t l e </w>', 460),
#              ('the m </w>', 460),
#              ('s h e </w>', 459),
#              ('o u t </w>', 443),
#              ('m u c h </w>', 434),
#              ('m a d e </w>', 430),
#              ('m an </w>', 428),
#              ('u s </w>', 420),
#              ('h o w e v er </w>', 408),
#              ('h er e </w>', 404),
#              ('e v e n </w>', 400),
#              ('g re a t </w>', 400),
#              ('t i m e </w>', 391),
#              ('f i r s t </w>', 391),
#              ('th u s </w>', 388),
#              ('w e l l </w>', 380),
#              ('s u c h </w>', 378),
#              ('b e f o re </w>', 376),
#              ('f o u n d </w>', 375),
#              ('o the r </w>', 371),
#              ('s h o u l d </w>', 370),
#              ('th r o u g h </w>', 370),
#              ('t w o </w>', 364),
#              ('m r </w>', 350),
#              ('o w n </w>', 342),
#              ('y e t </w>', 342),
#              ('y o u r </w>', 341),
#              ('l on g </w>', 340),
#              ('o v er </w>', 339),
#              ('d i d </w>', 337),
#              ('d o </w>', 336),
#              ('a f t er </w>', 327),
#              ('w h i l e </w>', 324),
#              ('m y s e l f </w>', 324),
#              ('m i g h t </w>', 321),
#              ('e v er y </w>', 319),
#              ('s t i l l </w>', 310),
#              ('m a y </w>', 310),
#              ('b e in g </w>', 306),
#              ('w i th o u t </w>', 305),
#              ('c an </w>', 298),
#              ('n e v er </w>', 297),
#              ('h a v in g </w>', 294),
#              ('l e n g th </w>', 293),
#              ('m u s t </w>', 288),
#              ('w h o l e </w>', 285),
#              ('e y e s </w>', 285),
#              ('on c e </w>', 280),
#              ('w i th in </w>', 276),
#              ('d o w n </w>', 273),
#              ('m an y </w>', 269),
#              ('o l d </w>', 266),
#              ('t o o </w>', 264),
#              ('th o s e </w>', 260),
#              ('in d e e d </w>', 257),
#              ('l i k e </w>', 253),
#              ('a l th o u g h </w>', 253),
#              ('th o u g h t </w>', 253),
#              ('h i m s e l f </w>', 252),
#              ('a m </w>', 250),
#              ('d a y </w>', 247),
#              ('n o th in g </w>', 247),
#              ('h o w </w>', 246),
#              ('w a y </w>', 243),
#              ('a g a in </w>', 243),
#              ('h e a d </w>', 239),
#              ('th in g </w>', 238),
#              ('f a r </w>', 235),
#              ('g o o d </w>', 226),
#              ('th re e </w>', 225),
#              ('j u s t </w>', 219),
#              ('s e e m e d </w>', 218),
#              ('l e t </w>', 217),
#              ('c a m e </w>', 216),
#              ('t </w>', 216),
#              ('s e e </w>', 215),
#              ('m a t t er </w>', 215),
#              ('f e w </w>', 212),
#              ('l e s s </w>', 208),
#              ('h an d </w>', 207),
#              ('m a k e </w>', 205),
#              ('s h a l l </w>', 203),
#              ('c o u r s e </w>', 200),
#              ('l e f t </w>', 199),
#              ('f a c t </w>', 198),
#              ('n i g h t </w>', 198),
#              ('m an n er </w>', 196),
#              ('w h er e </w>', 195),
#              ('w o r d s </w>', 194),
#              ('m e an s </w>', 193),
#              ('m in d </w>', 192),
#              ('b o d y </w>', 191),
#              ('s e e n </w>', 191),
#              ('s a m e </w>', 190),
#              ('i t s e l f </w>', 190),
#              ('f e e t </w>', 188),
#              ('i d e a </w>', 186),
#              ('e v er </w>', 185),
#              ('t o o k </w>', 184),
#              ('u n t i l </w>', 182),
#              ('d e a th </w>', 181),
#              ('p o in t </w>', 181),
#              ('b a c k </w>', 180),
#              ('d e </w>', 180),
#              ('k n o w </w>', 179),
#              ('g e n er a l </w>', 177),
#              ('d o u b t </w>', 175),
#              ('s a w </w>', 171),
#              ('d u r in g </w>', 171),
#              ('a m on g </w>', 167),
#              ('n a t u re </w>', 167),
#              ('l a r g e </w>', 166),
#              ('l e a s t </w>', 164),
#              ('p a r t </w>', 164),
#              ('p er s on </w>', 164),
#              ('w h o s e </w>', 163),
#              ('b e c a m e </w>', 163),
#              ('m o m e n t </w>', 163),
#              ('r i g h t </w>', 162),
#              ('n e a r l y </w>', 162),
#              ('w o r l d </w>', 160),
#              ('l i g h t </w>', 158),
#              ('a i r </w>', 158),
#              ('a l t o g e the r </w>', 156),
#              ('f u l l </w>', 155),
#              ('d o o r </w>', 155),
#              ('p l a c e </w>', 154),
#              ('i m m e d i a t e l y </w>', 153),
#              ('u n d er </w>', 153),
#              ('p er i o d </w>', 153),
#              ('b e t w e e n </w>', 152),
#              ('y e a r s </w>', 151),
#              ('e a c h </w>', 151),
#              ('h e a r t </w>', 151),
#              ('c h a r a c t er </w>', 151),
#              ('q u e s t i on </w>', 150),
#              ('l a y </w>', 149),
#              ('c er t a in </w>', 149),
#              ('f r i e n d </w>', 148),
#              ('n o r </w>', 147),
#              ('e n d </w>', 147),
#              ('l i f e </w>', 146),
#              ('o f f </w>', 145),
#              ('o </w>', 145),
#              ('f e l l </w>', 144),
#              ('a l s o </w>', 144),
#              ('e a r th </w>', 144),
#              ('th in g s </w>', 143),
#              ('t a k e </w>', 142),
#              ('r a the r </w>', 142),
#              ('v o i c e </w>', 141),
#              ('f e l t </w>', 140),
#              ('t r u th </w>', 140),
#              ('p er h a p s </w>', 140),
#              ('l a t t er </w>', 140),
#              ('s o on </w>', 139),
#              ('t r u e </w>', 138),
#              ('p u t </w>', 138),
#              ('h a l f </w>', 136),
#              ('a t t e n t i on </w>', 136),
#              ('s o u l </w>', 135),
#              ('f a c e </w>', 135),
#              ('g a v e </w>', 135),
#              ('l a s t </w>', 134),
#              ('th in k </w>', 134),
#              ('s u re </w>', 134),
#              ('d a y s </w>', 133),
#              ('r o o m </w>', 132),
#              ('th o u s an d </w>', 132),
#              ('w h y </w>', 131),
#              ('p re s e n t </w>', 131),
#              ('h e a r d </w>', 130),
#              ('w e n t </w>', 130),
#              ('o p e n </w>', 130),
#              ('a p p e a re d </w>', 130),
#              ('w a t er </w>', 129),
#              ('m er e </w>', 129),
#              ('c a l l e d </w>', 128),
#              ('n a m e </w>', 128),
#              ('h o u s e </w>', 127),
#              ('c a s e </w>', 127),
#              ('b e y on d </w>', 127),
#              ('re a s on </w>', 127),
#              ('w o r d </w>', 126),
#              ('p o s s i b l e </w>', 125),
#              ('m er e l y </w>', 125),
#              ('h o u r </w>', 123),
#              ('h u m an </w>', 123),
#              ('c an n o t </w>', 123),
#              ('e y e </w>', 122),
#              ('a b o v e </w>', 122),
#              ('a l w a y s </w>', 121),
#              ('q u i t e </w>', 121),
#              ('e i the r </w>', 121),
#              ('a p p e a r an c e </w>', 121),
#              ('a c c o u n t </w>', 120),
#              ('s m a l l </w>', 119),
#              ('l a d y </w>', 119),
#              ('m e n </w>', 118),
#              ('the re f o re </w>', 118),
#              ('k n o w n </w>', 117),
#              ('f in d </w>', 117),
#              ('a w a y </w>', 115),
#              ('an o the r </w>', 115),
#              ('p o r t i on </w>', 115),
#              ('d i f f i c u l t y </w>', 114),
#              ('a r o u n d </w>', 113),
#              ('d on e </w>', 113),
#              ('v i e w </w>', 112),
#              ('b o th </w>', 112),
#              ('s e c on d </w>', 112),
#              ('k n e w </w>', 111),
#              ('c o m e </w>', 110),
#              ('s o m e th in g </w>', 110),
#              ('t a k e n </w>', 109),
#              ('the m s e l v e s </w>', 109),
#              ('m in u t e s </w>', 109),
#              ('l o o k e d </w>', 108),
#              ('s e n s e </w>', 108),
#              ('a l on e </w>', 108),
#              ('h u n d re d </w>', 108),
#              ('f o u r </w>', 107),
#              ('w h o m </w>', 107),
#              ('g e n t l e m an </w>', 107),
#              ('g o d </w>', 106),
#              ('m o r n in g </w>', 106),
#              ('f o r m </w>', 105),
#              ('h o m e </w>', 105),
#              ('t u r n e d </w>', 105),
#              ('k in g </w>', 105),
#              ('s c a r c e l y </w>', 104),
#              ('o b j e c t </w>', 104),
#              ('s i r </w>', 104),
#              ('re p l i e d </w>', 104),
#              ('b l a c k </w>', 103),
#              ('a g a in s t </w>', 103),
#              ('o r d in a r y </w>', 103),
#              ('b a l l o on </w>', 103),
#              ('a l re a d y </w>', 103),
#              ('s t o o d </w>', 102),
#              ('— </w>', 102),
#              ('d i s c o v er e d </w>', 102),
#              ('w i l d </w>', 101),
#              ('g o </w>', 101),
#              ('c i t y </w>', 101),
#              ('s p i r i t </w>', 101),
#              ('f i v e </w>', 100),
#              ('e f f e c t </w>', 100),
#              ('d e e p </w>', 100),
#              ('c o r p s e </w>', 100),
#              ('g re w </w>', 100),
#              ('y o u n g </w>', 99),
#              ('s in c e </w>', 99),
#              ('o b s er v e d </w>', 99),
#              ('s i d e </w>', 97),
#              ('n e a r </w>', 97),
#              ('re g a r d </w>', 97),
#              ('l o o k </w>', 96),
#              ('b e a u t y </w>', 96),
#              ('m a d a m e </w>', 96),
#              ('s e v er a l </w>', 96),
#              ('c on t in u e d </w>', 96),
#              ('g e t </w>', 95),
#              ('v a s t </w>', 95),
#              ('n a t u r a l </w>', 95),
#              ('a r m </w>', 95),
#              ('k in d </w>', 95),
#              ('t e l l </w>', 94),
#              ('b e d </w>', 94),
#              ('p a s s e d </w>', 94),
#              ('b e n e a th </w>', 94),
#              ('c h a m b er </w>', 94),
#              ('b e s t </w>', 93),
#              ('g i v e </w>', 93),
#              ('m e an </w>', 93),
#              ('b r o u g h t </w>', 92),
#              ('b e l i e v e </w>', 92),
#              ('l </w>', 92),
#              ('c i r c u m s t an c e s </w>', 92),
#              ('b e t t er </w>', 92),
#              ('l on g er </w>', 92),
#              ('s p e a k </w>', 91),
#              ('i m p o s s i b l e </w>', 91),
#              ('l o v e </w>', 91),
#              ('m </w>', 90),
#              ('g i v e n </w>', 90),
#              ('h i g h </w>', 89),
#              ('s e t </w>', 89),
#              ('c a l l </w>', 89),
#              ('e s p e c i a l l y </w>', 89),
#              ('re a l l y </w>', 89),
#              ('n e w </w>', 87),
#              ('p er c e i v e </w>', 87),
#              ('p o s i t i on </w>', 87),
#              ('s o u n d </w>', 86),
#              ('u s u a l </w>', 86),
#              ('c l o c k </w>', 86),
#              ('s u d d e n l y </w>', 85),
#              ('s u r f a c e </w>', 85),
#              ('r i v er </w>', 85),
#              ('d a r k </w>', 84),
#              ('s p o k e </w>', 84),
#              ('b o x </w>', 84),
#              ('n e c e s s a r y </w>', 83),
#              ('s o m e w h a t </w>', 83),
#              ('e x t e n t </w>', 83),
#              ('t a b l e </w>', 83),
#              ('f i g u re </w>', 83),
#              ('t i m e s </w>', 82),
#              ('p e o p l e </w>', 82),
#              ('s i m i l a r </w>', 82),
#              ('th r o w n </w>', 82),
#              ('m o u th </w>', 82),
#              ('in t er e s t </w>', 82),
#              ('d e g re e </w>', 82),
#              ('a r o s e </w>', 81),
#              ('c l o s e </w>', 81),
#              ('s a y s </w>', 81),
#              ('s u b j e c t </w>', 81),
#              ('s u p p o s e d </w>', 81),
#              ('s in g u l a r </w>', 81),
#              ('l e t t er </w>', 81),
#              ('re m a in e d </w>', 81),
#              ('p a r t y </w>', 80),
#              ('b u s in e s s </w>', 80),
#              ('p o w er </w>', 80),
#              ('c on d i t i on </w>', 80),
#              ('e n t i re l y </w>', 80),
#              ('h o u r s </w>', 79),
#              ('t e n </w>', 79),
#              ('l a t e </w>', 79),
#              ('f an c y </w>', 79),
#              ('h o r r o r </w>', 78),
#              ('l o w </w>', 78),
#              ('f u l l y </w>', 78),
#              ('s in g l e </w>', 78),
#              ('c o m p an y </w>', 78),
#              ('re s u l t </w>', 78),
#              ('s e a </w>', 77),
#              ('d e a d </w>', 77),
#              ('p u r p o s e </w>', 77),
#              ('c o u n t e n an c e </w>', 77),
#              ('e n t er e d </w>', 77),
#              ('s h o r t </w>', 76),
#              ('s t a t e </w>', 76),
#              ('r o u n d </w>', 75),
#              ('y e s </w>', 75),
#              ('in s t an t </w>', 75),
#              ('p a p er </w>', 75),
#              ('a p p a re n t </w>', 75),
#              ('re m a r k a b l e </w>', 75),
#              ('re m e m b er </w>', 75),
#              ('s i x </w>', 74),
#              ('s u p p o s e </w>', 74),
#              ('t o g e the r </w>', 74),
#              ('m a c h in e </w>', 74),
#              ('f in a l l y </w>', 74),
#              ('e n t i re </w>', 74),
#              ('f e e l </w>', 73),
#              ('w a l l </w>', 73),
#              ('d e s i g n </w>', 73),
#              ('e v i d e n c e </w>', 73),
#              ('p r o c e e d e d </w>', 72),
#              ('n e x t </w>', 72),
#              ('l o o k in g </w>', 72),
#              ('in d i v i d u a l </w>', 72),
#              ('c on s i d er e d </w>', 72),
#              ('a t t e m p t </w>', 71),
#              ('s u n </w>', 71),
#              ('p e c u l i a r </w>', 71),
#              ('b e c a u s e </w>', 71),
#              ('d </w>', 71),
#              ('m a r i e </w>', 71),
#              ('d u p in </w>', 71),
#              ('d i s t an c e </w>', 71),
#              ('h an d s </w>', 71),
#              ('p r o p er </w>', 71),
#              ('s u f f i c i e n t </w>', 70),
#              ('s u f f i c i e n t l y </w>', 70),
#              ('a r t </w>', 70),
#              ('m a in </w>', 70),
#              ('m a k in g </w>', 70),
#              ('e x t re m e </w>', 70),
#              ('a w a re </w>', 70),
#              ('d i re c t i on </w>', 70),
#              ('e x p re s s i on </w>', 70),
#              ('l o s t </w>', 69),
#              ('s t r an g e </w>', 69),
#              ('a t m o s p h er e </w>', 69),
#              ('s a t </w>', 68),
#              ('e v i d e n t </w>', 68),
#              ('f a r the r </w>', 68),
#              ('n u m b er </w>', 68),
#              ('p re c i s e l y </w>', 68),
#              ('h o l d </w>', 67),
#              ('b r i e f </w>', 67),
#              ('e x c e e d in g l y </w>', 67),
#              ('t er r o r </w>', 67),
#              ('a p p a re n t l y </w>', 67),
#              ('o h </w>', 66),
#              ('n o s e </w>', 66),
#              ('f in e </w>', 66),
#              ('n on e </w>', 66),
#              ('o p in i on </w>', 66),
#              ('s h a d o w </w>', 65),
#              ('a l m o s t </w>', 65),
#              ('c l e a r </w>', 65),
#              ('f o r c e </w>', 65),
#              ('b e a u t i f u l </w>', 65),
#              ('f l o o r </w>', 65),
#              ('e x a m p l e </w>', 65),
#              ('n e i the r </w>', 65),
#              ('u n d er s t an d </w>', 65),
#              ('re c e i v e d </w>', 65),
#              ('s i g h t </w>', 64),
#              ('s e v e n </w>', 64),
#              ('e n o u g h </w>', 64),
#              ('u s e </w>', 64),
#              ('s i m p l e </w>', 64),
#              ('m in u t e </w>', 64),
#              ('o r i g in a l </w>', 64),
#              ('p l a c e d </w>', 63),
#              ('m i l e s </w>', 63),
#              ('l e d </w>', 63),
#              ('p a r t i c u l a r </w>', 63),
#              ('a g e </w>', 63),
#              ('s e n t i m e n t </w>', 63),
#              ('w i f e </w>', 63),
#              ('h u n g </w>', 62),
#              ('w a l l s </w>', 62),
#              ('th i r d </w>', 62),
#              ('t a k in g </w>', 62),
#              ('m e an t i m e </w>', 62),
#              ('w h a t e v er </w>', 62),
#              ('re s p e c t </w>', 62),
#              ('w h i t e </w>', 61),
#              ('h e i g h t </w>', 61),
#              ('c a r </w>', 61),
#              ('f e e l in g </w>', 61),
#              ('m on s i e u r </w>', 61),
#              ('b o t t o m </w>', 60),
#              ('o f t e n </w>', 60),
#              ('d o e s </w>', 60),
#              ('h u g e </w>', 60),
#              ('b e c o m e </w>', 60),
#              ('l i p s </w>', 60),
#              ('f a m i l y </w>', 60),
#              ('w o r k </w>', 60),
#              ('p r in c i p l e </w>', 60),
#              ('o c c u r re d </w>', 60),
#              ('s c e n e </w>', 59),
#              ('p </w>', 59),
#              ('e v e n t s </w>', 59),
#              ('e x t r a o r d in a r y </w>', 59),
#              ('p o in t s </w>', 59),
#              ('j u p i t er </w>', 59),
#              ('a u t o m a t on </w>', 59),
#              ('p er s on a l </w>', 59),
#              ('a c t u a l l y </w>', 58),
#              ('s l i g h t </w>', 58),
#              ('o the r s </w>', 58),
#              ('m a t er i a l </w>', 58),
#              ('c a u s e </w>', 57),
#              ('f o o t </w>', 57),
#              ('h o p e </w>', 57),
#              ('e a s i l y </w>', 57),
#              ('k n o w l e d g e </w>', 57),
#              ('in s t an c e </w>', 57),
#              ('u t t er l y </w>', 57),
#              ('c o m m on </w>', 57),
#              ('re g a r d e d </w>', 57),
#              ('f i re </w>', 57),
#              ('i m m e d i a t e </w>', 56),
#              ('m e m o r y </w>', 56),
#              ('t o l d </w>', 56),
#              ('g e n i u s </w>', 56),
#              ('a p a r t m e n t </w>', 56),
#              ('h a </w>', 56),
#              ('l in e </w>', 56),
#              ('in t e n s e </w>', 56),
#              ('— an d </w>', 56),
#              ('m o on </w>', 56),
#              ('b re a th </w>', 56),
#              ('g re a t er </w>', 56),
#              ('p a s s a g e </w>', 55),
#              ('s o l e </w>', 55),
#              ('t r o u b l e </w>', 55),
#              ('o d d </w>', 55),
#              ('w in d o w </w>', 55),
#              ('e v e n in g </w>', 55),
#              ('w in e </w>', 55),
#              ('l e a v in g </w>', 55),
#              ('t er r i b l e </w>', 55),
#              ('m u r d er </w>', 55),
#              ('m e n t i on e d </w>', 55),
#              ('t on e </w>', 55),
#              ('th re w </w>', 55),
#              ('s p o t </w>', 54),
#              ('h e l d </w>', 54),
#              ('a m i d </w>', 54),
#              ('a b l e </w>', 54),
#              ('p r o f o u n d </w>', 54),
#              ('s t e p </w>', 54),
#              ('l e </w>', 54),
#              ('p o e m </w>', 54),
#              ('v a in </w>', 54),
#              ('d i s t in c t </w>', 54),
#              ('re a d </w>', 54),
#              ('e x c i t e d </w>', 53),
#              ('b e l o w </w>', 53),
#              ('a c c i d e n t </w>', 53),
#              ('e i g h t </w>', 53),
#              ('o p e n e d </w>', 53),
#              ('h a i r </w>', 53),
#              ('g o l d </w>', 53),
#              ('p u b l i c </w>', 53),
#              ('b r in g </w>', 53),
#              ('re s t </w>', 53),
#              ('re t u r n </w>', 53),
#              ('c a re f u l l y </w>', 53),
#              ('s h i p </w>', 52),
#              ('t u r n </w>', 52),
#              ('y e a r </w>', 52),
#              ('h e l p </w>', 52),
#              ('f i f t y </w>', 52),
#              ('s u c c e e d e d </w>', 52),
#              ('i m a g in e </w>', 52),
#              ('f o r m er </w>', 52),
#              ('p er f e c t </w>', 52),
#              ('s t r on g </w>', 52),
#              ('— b u t </w>', 51),
#              ('s e a r c h </w>', 51),
#              ('c u t </w>', 51),
#              ('e a r s </w>', 51),
#              ('a b s o l u t e l y </w>', 51),
#              ('e f f o r t </w>', 51),
#              ('f r i e n d s </w>', 51),
#              ('f o r th </w>', 51),
#              ('an i m a l </w>', 51),
#              ('p er c e i v e d </w>', 51),
#              ('n e v er the l e s s </w>', 51),
#              ('m o t i on </w>', 51),
#              ('p re s e n c e </w>', 51),
#              ('r a p i d l y </w>', 50),
#              ('e x i s t e n c e </w>', 50),
#              ('f a l l </w>', 50),
#              ('f o r m e d </w>', 50),
#              ('e v i d e n t l y </w>', 50),
#              ('a r r i v e d </w>', 50),
#              ('b l o o d </w>', 50),
#              ('d e a r </w>', 50),
#              ('c </w>', 50),
#              ('in t e l l e c t </w>', 50),
#              ('p r o p er l y </w>', 50),
#              ('d i s c o v er y </w>', 50),
#              ('a s t on i s h m e n t </w>', 50),
#              ('t re e </w>', 50),
#              ('a g o </w>', 49),
#              ('v i s i b l e </w>', 49),
#              ('h e a r </w>', 49),
#              ('d i f f i c u l t </w>', 49),
#              ('a b s o l u t e </w>', 49),
#              ('a r m s </w>', 49),
#              ('b o s o m </w>', 49),
#              ('p o o r </w>', 49),
#              ('th o u </w>', 49),
#              ('w h e the r </w>', 49),
#              ('m o the r </w>', 49),
#              ('w in d </w>', 49),
#              ('p er s on s </w>', 49),
#              ('re a c h e d </w>', 49),
#              ('m e a s u re </w>', 49),
#              ('p l e a s u re </w>', 49),
#              ('re p l y </w>', 49),
#              ('k e p t </w>', 48),
#              ('h e a v e n </w>', 48),
#              ('t o w a r d </w>', 48),
#              ('f e l l o w </w>', 48),
#              ('p h y s i c a l </w>', 48),
#              ('m a j e s t y </w>', 48),
#              ('in f l u e n c e </w>', 48),
#              ('g on e </w>', 48),
#              ('v i s i on </w>', 48),
#              ('c on s i d er a t i on </w>', 48),
#              ('c on v er s a t i on </w>', 48),
#              ('re a d i l y </w>', 48),
#              ('s e c re t </w>', 48),
#              ('re n d er e d </w>', 48),
#              ('s i z e </w>', 47),
#              ('o u r s e l v e s </w>', 47),
#              ('b o a t </w>', 47),
#              ('m o r a l </w>', 47),
#              ('s p e c i e s </w>', 47),
#              ('a s k e d </w>', 47),
#              ('g i r l </w>', 47),
#              ('b e h in d </w>', 47),
#              ('p a in </w>', 47),
#              ('b e g an </w>', 47),
#              ('m e an in g </w>', 47),
#              ('d on </w>', 47),
#              ('g re a t l y </w>', 47),
#              ('re d </w>', 47),
#              ('p u re </w>', 47),
#              ('w i d e </w>', 46),
#              ('u n u s u a l </w>', 46),
#              ('w i s h </w>', 46),
#              ('e s c a p e </w>', 46),
#              ('a l a s </w>', 46),
#              ('t a l l </w>', 46),
#              ('s a t i s f i e d </w>', 46),
#              ('s i l e n c e </w>', 46),
#              ('p i e c e </w>', 46),
#              ('g e t t in g </w>', 46),
#              ('c a p t a in </w>', 46),
#              ('c h an g e </w>', 46),
#              ('a c q u a in t an c e </w>', 46),
#              ('d i f f er e n t </w>', 46),
#              ('o r d er </w>', 46),
#              ('in t er i o r </w>', 46),
#              ('p o s s e s s i on </w>', 46),
#              ('f a s h i on </w>', 46),
#              ('v on </w>', 46),
#              ('i m a g in a t i on </w>', 46),
#              ('t re e s </w>', 46),
#              ('b o re </w>', 46),
#              ('c a re </w>', 46),
#              ('v a r i o u s </w>', 45),
#              ('f a i l </w>', 45),
#              ('s w e e t </w>', 45),
#              ('d i e d </w>', 45),
#              ('w e i g h t </w>', 45),
#              ('b o o k </w>', 45),
#              ('t e e th </w>', 45),
#              ('th o u g h t s </w>', 45),
#              ('— the </w>', 45),
#              ('b u i l d in g </w>', 45),
#              ('in c h e s </w>', 45),
#              ('g i v in g </w>', 45),
#              ('a c t i on </w>', 45),
#              ('g re e n </w>', 45),
#              ('s t re e t </w>', 45),
#              ('t o p </w>', 44),
#              ('b o a r d </w>', 44),
#              ('e x c i t e m e n t </w>', 44),
#              ('p a r i s </w>', 44),
#              ('f a i r </w>', 44),
#              ('g a m e </w>', 44),
#              ('s e e m s </w>', 44),
#              ('th o r o u g h l y </w>', 44),
#              ('c i r c u m s t an c e </w>', 44),
#              ('w o m an </w>', 44),
#              ('l e g r an d </w>', 44),
#              ('m a t t er s </w>', 44),
#              ('b a r on </w>', 44),
#              ('f r a m e </w>', 43),
#              ('h a p p e n e d </w>', 43),
#              ('g r o u n d </w>', 43),
#              ('l o u d </w>', 43),
#              ('m e t </w>', 43),
#              ('c o m m i t t e d </w>', 43),
#              ('t w e n t y </w>', 43),
#              ('c o l o r </w>', 43),
#              ('d o c t o r </w>', 43),
#              ('m a d </w>', 43),
#              ('th r o u g h o u t </w>', 43),
#              ('g o in g </w>', 43),
#              ('m y s t er y </w>', 43),
#              ('o c c a s i on e d </w>', 43),
#              ('h on o r </w>', 43),
#              ('b on - b on </w>', 43),
#              ('w on d er </w>', 43),
#              ('re a l </w>', 43),
#              ('re m a in </w>', 43),
#              ('e x c e p t </w>', 42),
#              ('n a r r o w </w>', 42),
#              ('h e a v y </w>', 42),
#              ('m o v e </w>', 42),
#              ('v a l l e y </w>', 42),
#              ('f a i l e d </w>', 42),
#              ('g e n t l e m e n </w>', 42),
#              ('f i l l e d </w>', 42),
#              ('b i g </w>', 42),
#              ('w in d o w s </w>', 42),
#              ('l i v in g </w>', 42),
#              ('i m p o r t an t </w>', 42),
#              ('t er m </w>', 42),
#              ('c o r n er </w>', 42),
#              ('e l e v a t i on </w>', 42),
#              ('re a c h </w>', 42),
#              ('e x p e c t e d </w>', 41),
#              ('l e g s </w>', 41),
#              ('p o e t </w>', 41),
#              ('o b j e c t s </w>', 41),
#              ('n e e d </w>', 41),
#              ('r i c h </w>', 41),
#              ('b e s i d e s </w>', 41),
#              ('e d i t o r </w>', 41),
#              ('e v i l </w>', 41),
#              ('s y s t e m </w>', 41),
#              ('r u e </w>', 41),
#              ('o b t a in e d </w>', 41),
#              ('a t t a in e d </w>', 41),
#              ('an y th in g </w>', 41),
#              ('t er m e d </w>', 41),
#              ('er r o r </w>', 41),
#              ('u n d er s t o o d </w>', 41),
#              ('a l on g </w>', 41),
#              ('o b s er v a t i on </w>', 41),
#              ('p re p a re d </w>', 41),
#              ('d e s i re </w>', 41),
#              ('p re f e c t </w>', 41),
#              ('f e e b l e </w>', 40),
#              ('s u n d a y </w>', 40),
#              ('h i d e o u s </w>', 40),
#              ('d e s c e n t </w>', 40),
#              ('p a s s </w>', 40),
#              ('p r o v e d </w>', 40),
#              ('s l e e p </w>', 40),
#              ('c r o w d </w>', 40),
#              ('p r o c e e d </w>', 40),
#              ('d a r k n e s s </w>', 40),
#              ('s t </w>', 40),
#              ('s h o w </w>', 40),
#              ('o the r w i s e </w>', 40),
#              ('d i s t in c t l y </w>', 40),
#              ('in t e n d e d </w>', 40),
#              ('l o w er </w>', 40),
#              ('s u s p i c i on </w>', 40),
#              ('m on th s </w>', 40),
#              ('f re q u e n t l y </w>', 40),
#              ('re s o l v e d </w>', 40),
#              ('p re s e n t e d </w>', 40),
#              ('re f l e c t i on </w>', 40),
#              ('e l s e </w>', 39),
#              ('c o u n t r y </w>', 39),
#              ('p a l e </w>', 39),
#              ('a p p e a r s </w>', 39),
#              ('c l o s e d </w>', 39),
#              ('c u r i o s i t y </w>', 39),
#              ('e q u a l </w>', 39),
#              ('a d m i t t e d </w>', 39),
#              ('d r </w>', 39),
#              ('s t e p s </w>', 39),
#              ('c h a i r </w>', 39),
#              ('p o s i t i v e </w>', 39),
#              ('f e a r </w>', 39),
#              ('s p o k e n </w>', 39),
#              ('e n a b l e d </w>', 39),
#              ('k e e p </w>', 39),
#              ('l l </w>', 39),
#              ('n e c e s s i t y </w>', 39),
#              ('f o r th w i th </w>', 39),
#              ('v i c in i t y </w>', 39),
#              ('d o in g </w>', 39),
#              ('s p e a k in g </w>', 39),
#              ('th in </w>', 39),
#              ('l an g u a g e </w>', 39),
#              ('a f t er w a r d </w>', 39),
#              ('f l o w er s </w>', 39),
#              ('d e t er m in e d </w>', 39),
#              ('s h o re </w>', 39),
#              ('c o m p re h e n d </w>', 39),
#              ('d re a m </w>', 39),
#              ('re t u r n e d </w>', 39),
#              ('re f er e n c e </w>', 39),
#              ('b r o k e n </w>', 38),
#              ('g a z e d </w>', 38),
#              ('s e n s e s </w>', 38),
#              ('m a g n i f i c e n t </w>', 38),
#              ('h a p p y </w>', 38),
#              ('r o l l e d </w>', 38),
#              ('g r a c e </w>', 38),
#              ('c a t </w>', 38),
#              ('n a t u r a l l y </w>', 38),
#              ('w r i t e </w>', 38),
#              ('e p o c h </w>', 38),
#              ('s e a t </w>', 38),
#              ('l e a v e </w>', 38),
#              ('e m p l o y e d </w>', 38),
#              ('o b v i o u s </w>', 38),
#              ('h i the r t o </w>', 38),
#              ('f o l l o w in g </w>', 38),
#              ('th in k in g </w>', 38),
#              ('g l an c e </w>', 38),
#              ('i m p o r t an c e </w>', 38),
#              ('g e n er a l l y </w>', 38),
#              ('s er i e s </w>', 38),
#              ('c on c l u s i on </w>', 38),
#              ('p r o p o r t i on </w>', 38),
#              ('p r o g re s s </w>', 38),
#              ('y o u r s e l f </w>', 37),
#              ('v i o l e n c e </w>', 37),
#              ('g e n t l e </w>', 37),
#              ('e a r </w>', 37),
#              ('m i d d l e </w>', 37),
#              ('c e a s e d </w>', 37),
#              ('a r t i c l e s </w>', 37),
#              ('f a t e </w>', 37),
#              ('s h a p e </w>', 37),
#              ('y e </w>', 37),
#              ('v </w>', 37),
#              ('b </w>', 37),
#              ('l i e </w>', 37),
#              ('o c c u p i e d </w>', 37),
#              ('m r s </w>', 37),
#              ('s t y l e </w>', 37),
#              ('m a e l z e l </w>', 37),
#              ('f o u r th </w>', 37),
#              ('f e e l in g s </w>', 37),
#              ('l an d </w>', 37),
#              ('an g e l </w>', 37),
#              ('o b s er v e </w>', 37),
#              ('u p p er </w>', 37),
#              ('d a u g h t er </w>', 37),
#              ('e x c e p t i on </w>', 37),
#              ('c on s e q u e n c e </w>', 37),
#              ('m on e y </w>', 37),
#              ('e l l i s on </w>', 37),
#              ('w o re </w>', 37),
#              ('a r re s t e d </w>', 37),
#              ('f o re v er </w>', 37),
#              ('f r o </w>', 36),
#              ('e a r l y </w>', 36),
#              ('g o t </w>', 36),
#              ('f o o l </w>', 36),
#              ('p o s s e s s e d </w>', 36),
#              ('s t e a d i l y </w>', 36),
#              ('d e s c r i b e d </w>', 36),
#              ('n o t i c e </w>', 36),
#              ('f o l l o w e d </w>', 36),
#              ('d e p a r t e d </w>', 36),
#              ('u n k n o w n </w>', 36),
#              ('w r i t t e n </w>', 36),
#              ('u s u a l l y </w>', 36),
#              ('a r t i c l e </w>', 36),
#              ('g l a s s </w>', 36),
#              ('s u g g e s t e d </w>', 36),
#              ('d e p o s i t e d </w>', 36),
#              ('l a </w>', 36),
#              ('p o l i c e </w>', 36),
#              ('s a y in g </w>', 36),
#              ('n in e </w>', 36),
#              ('b r a in </w>', 36),
#              ('o c e an </w>', 36),
#              ('g i g an t i c </w>', 36),
#              ('l e t t er s </w>', 36),
#              ('p er </w>', 36),
#              ('m a s t er </w>', 36),
#              ('s u f f er e d </w>', 36),
#              ('in t er v a l s </w>', 36),
#              ('an s w er </w>', 36),
#              ('u n d er s t an d in g </w>', 36),
#              ('o c c a s i on </w>', 36),
#              ('g h a s t l y </w>', 35),
#              ('b e a r </w>', 35),
#              ('f o r c e d </w>', 35),
#              ('b u r i e d </w>', 35),
#              ('m o m e n t s </w>', 35),
#              ('d o g </w>', 35),
#              ('p o m p e y </w>', 35),
#              ('i d e a s </w>', 35),
#              ('m u s i c </w>', 35),
#              ('p o s s i b l y </w>', 35),
#              ('e x c e s s i v e l y </w>', 35),
#              ('f a l l e n </w>', 35),
#              ('e x c e l l e n t </w>', 35),
#              ('e a s t </w>', 35),
#              ('m o v e m e n t </w>', 35),
#              ('w i d </w>', 35),
#              ('g o o d f e l l o w </w>', 35),
#              ('d r a w in g </w>', 35),
#              ('i s l an d </w>', 35),
#              ('q u an t i t y </w>', 35),
#              ('m an k in d </w>', 35),
#              ('n u m er o u s </w>', 35),
#              ('o f f er e d </w>', 35),
#              ('s i l v er </w>', 35),
#              ('s er i o u s </w>', 35),
#              ('a f t er w a r d s </w>', 35),
#              ('d r a w er </w>', 35),
#              ('s i t u a t i on </w>', 35),
#              ('i r on </w>', 35),
#              ('p a s s i on </w>', 35),
#              ('re m o t e </w>', 35),
#              ('d e g re e s </w>', 35),
#              ('p re s u m e </w>', 35),
#              ('i m p re s s i on </w>', 35),
#              ('o p p o s i t e </w>', 34),
#              ('n o i s e </w>', 34),
#              ('o p p o r t u n i t y </w>', 34),
#              ('s a v e </w>', 34),
#              ('a p p e a r </w>', 34),
#              ('d e s p a i r </w>', 34),
#              ('s l o w l y </w>', 34),
#              ('b o d i e s </w>', 34),
#              ('n e c k </w>', 34),
#              ('a i d </w>', 34),
#              ('v a g u e </w>', 34),
#              ('t o w n </w>', 34),
#              ('d o o r s </w>', 34),
#              ('g r a v e </w>', 34),
#              ('s a d </w>', 34),
#              ('l i e s </w>', 34),
#              ('t a s t e </w>', 34),
#              ('— a </w>', 34),
#              ('s k u l l </w>', 34),
#              ('a c c o m p l i s h e d </w>', 34),
#              ('the e </w>', 34),
#              ('c o m in g </w>', 34),
#              ('e x p er i e n c e </w>', 34),
#              ('m a c h in er y </w>', 34),
#              ('c on t e m p l a t i on </w>', 34),
#              ('a s t on i s h e d </w>', 34),
#              ('f r on t </w>', 34),
#              ('e x a m in a t i on </w>', 34),
#              ('c on s i d er </w>', 34),
#              ('c e n t re </w>', 34),
#              ('d re a m s </w>', 34),
#              ('s t re n g th </w>', 34),
#              ('in c re a s e d </w>', 34),
#              ('p a s t </w>', 33),
#              ('l i m b s </w>', 33),
#              ('s t o r y </w>', 33),
#              ('g r a d u a l l y </w>', 33),
#              ('p r o d i g i o u s </w>', 33),
#              ('d e t a i l s </w>', 33),
#              ('a f f o r d </w>', 33),
#              ('s l i g h t e s t </w>', 33),
#              ...])
